# %% [markdown]
# 328
# Zweierpotenz (Power Of Two)
# Anfänger - Pythonvon JKooP - 06.03.2021 um 11:51 Uhr
# Erstelle eine Methode/Funktion, mit der man bestimmen kann,
# ob die übergebene Zahl als Ganzzahl- Potenz (Integer) zur Basis 2 geschrieben werden kann.
#
# Beispiele:
#
# Zahl: 1 => true
# Lösung: 0, denn 2 hoch 0 = 1
#
# Zahl: 16 => true
# Lösung: 4, denn 2 hoch 4 = 16
#
# Zahl: 3 => false
# Lösung: keine, da keine Ganzzahl zur Basis 2 die Zahl 3 ergibt
#
# Für Fortgeschrittene:
# Die Aufgabe ohne Zuhilfenahme der eingebauten Logarithmusfunktionen lösen.
#
# Viel Spaß
#
# https://trainyourprogrammer.de/python

# %%
def isPowOf2(n):
    i=0
    while n > 1:
        i += 1
        if n & 1 == 1:
            i=0
            break
        n >>= 1
    return i # != 0

# %%
import time
xArr=[2**44497,1024,777777]
for x in xArr:
    t0=time.time()
    r=isPowOf2(x)
    t1=time.time()-t0
    print(str(r)+"\t"+str(t1))
# Out:
# 44497	0.10994982719421387
# 10	3.337860107421875e-06
# 0	1.1920928955078125e-06
