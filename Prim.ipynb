# %%
def isPrim(n):
    r=0
    sqrtN=int(n**.5+1.1)
    if n%2 == 0: return 2
    for i in range(3,sqrtN,2): 
        if n%i == 0:
            r=i; break
    return r

# %%
isPrim(909009809808008080808080801)
# Out:
# 6469

# %%
6803/7
# Out:
# 971.8571428571429

# %%
99**999
# Out:
# ...
