# %%
import random
import time
#szaehler = input("Mit wievielen Zufallszahlen soll versucht werden, pi zu finden?: ")
counter_in = 0
zaehler=100000000 # int(szaehler)
t0=time.time()
for i in range(zaehler):
    x = random.random()
    y = random.random()
    
    if x*x + y*y < 1:
        counter_in += 1
t1=time.time()-t0
        
pi = float(4*counter_in)/zaehler
 
print (pi, t1)
# Out:
# 3.14164088 47.59882473945618

# %% [markdown]
# Zusatzaufgabe: Berechnen Sie nach dem selben Verfahren die Fläche unter der Parabelkurve  im Intervall 0.0 bis 1.0. Mathematisch berechnet müsste das Resultat bei 1/3 liegen. Suchen Sie das Quadrat und entscheiden Sie, mit welcher Berechnung Sie herausfinden, ob ein Punkt unter oder über der Kurve liegt. Zählen Sie wieder 10 000 Punkte.

# %%
import random
import time
#szaehler = input("Mit wievielen Zufallszahlen soll versucht werden, pi zu finden?: ")
counter_in = 0
zaehler=100000 # int(szaehler)
t0=time.time()
for i in range(zaehler):
    x = random.random()
    y = random.random()
    
    if y < x*x:
        counter_in += 1
t1=time.time()-t0
        
pi = float(1*counter_in)/zaehler
 
print (pi, t1)
# Out:
# 0.33532 0.04622483253479004
